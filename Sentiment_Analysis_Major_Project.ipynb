# %% [markdown]
# <a href="https://colab.research.google.com/github/Dedeepya-1020/Sentiment-analysis--Major-project/blob/main/Sentiment_Analysis_Major_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install vaderSentiment
# Out:
# ...
#      |████████████████████████████████| 133kB 6.0MB/s
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs=SentimentIntensityAnalyzer()

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
url='https://inshorts.com/en/read/sports'
news_data=[]
news_category=url.split('/')[-1]
data=requests.get(url)
soup=BeautifulSoup(data.content)
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
# ...

# %%
urls=['https://inshorts.com/en/read/sports',
      'https://inshorts.com/en/read/world',
      'https://inshorts.com/en/read/politics']
def build_dataset(urls) :
  news_data=[]
  for url in urls :
    news_category=url.split('/')[-1]
    data=requests.get(url)
    soup=BeautifulSoup(data.content)

    news_articles=[{'news_headline':headline.find('span',attrs={"itemprop":"headline"}).string,
                   'news_article':article.find('div',attrs={"itemprop":"articleBody"}).string,
                    'news_category':news_category}
                   
                   for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),
                                               soup.find_all('div',class_=["news-card-content news-right-box"]))]
    news_articles = news_articles[0:20]
    news_data.extend(news_articles)

  df = pd.DataFrame(news_data)
  df = df [['news_headline','news_article','news_category']]
  return df

# %%
df= build_dataset(urls)
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  KKR & NZ pacer Lockie Ferguson develops fast b...  ...        sports
# 1  Dwayne Smith smashes six sixes in an over agai...  ...        sports
# 2  Lala you're 100% right: Amir on Afridi's tweet...  ...        sports
# 3  Cricket Australia criticises Channel 7 over st...  ...        sports
# 4  Natarajan becomes India's 232nd ODI cricketer,...  ...        sports
#
# [5 rows x 3 columns]

# %%
df= build_dataset(urls)
df.tail()
# Out:
#                                         news_headline  ... news_category
# 55  Where has all the money of PM CARES Fund gone:...  ...      politics
# 56  35.8% voter turnout recorded till 5 pm in GHMC...  ...      politics
# 57  TMC will cease to exist in a month: BJP's Dili...  ...      politics
# 58  Never called farmers' protest politically moti...  ...      politics
# 59  Massive cycle of religious conversion going on...  ...      politics
#
# [5 rows x 3 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Dedeepya-1020/Sentiment-analysis--Major-project/main/news.csv')
df
# Out:
#                                         news_headline  ... news_category
# 0   How many batsmen have scored 99 runs in an inn...  ...        sports
# 1   Cricket Australia criticises Channel 7 over st...  ...        sports
# 2   Warner's wife jokingly suggests sex reason beh...  ...        sports
# 3   Female footballer refuses to pay tribute to Ma...  ...        sports
# 4   Afridi gets angry at 21-yr-old Afghan pacer ov...  ...        sports
# 5   F1 world champion Lewis Hamilton tests positiv...  ...        sports
# 6   Natarajan becomes India's 232nd ODI cricketer,...  ...        sports
# 7   Kohli becomes fastest batsman to hit 12,000 OD...  ...        sports
# 8   It does feel nice: Babar Azam on comparison wi...  ...        sports
# 9   KKR & NZ pacer Lockie Ferguson develops fast b...  ...        sports
# 10  29-yr-old Spanish tennis player banned for 8 y...  ...        sports
# 11  Dwayne Smith smashes six sixes in an over agai...  ...        sports
# ...

# %%
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 177

# %%
def html_tag(text):
  soup = BeautifulSoup(text,"html.parser")
  new_text =soup.get_text()
  return new_text

html_tag('<html><h2> some important info </h2></html>')
# Out:
# ' some important info '

# %%
# !pip install contractions
import contractions
def con(text):
   expand = contractions.fix(text)
   return expand
# Out:
# ...
#      |████████████████████████████████| 245kB 5.7MB/s
# ...
#      |████████████████████████████████| 317kB 30.9MB/s
# ...
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.0-cp36-cp36m-linux_x86_64.whl size=81700 sha256=ed6c50f07aff943170452a2f71ccfdd83b8ad55343804db7c95381ab8d45ff0d
#   Stored in directory: /root/.cache/pip/wheels/0a/90/61/87a55f5b459792fbb2b7ba6b31721b06ff5cf6bde541b40994
# Successfully built pyahocorasick
# ...

# %%
import re
def remove_sp(text):
  pattern = r'[^A-Za-z0-9]'
  text=re.sub(pattern,'',text)
  return text

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()

# %%
def remove_stopwords(text):
  tokens = tokenizer.tokenize(text)
  tokens = [token.strip() for token in tokens]
  filtered_tokens = [token for token in tokens if token not in  stopword_list]
  filtered_text = ''.join(filtered_tokens)
  return filtered_text

# %%
df.news_headline = df.news_headline.apply(lambda x:x.lower())
df.news_article = df.news_article.apply(lambda x:x.lower())

df.news_headline = df.news_headline.apply(html_tag)
df.news_article = df.news_article.apply(html_tag)

df.news_headline = df.news_headline.apply(con)
df.news_article = df.news_article.apply(con)

df.news_headline = df.news_headline.apply(remove_sp)
df.news_article = df.news_article.apply(remove_sp)

df.news_headline = df.news_headline.apply(remove_stopwords)
df.news_article = df.news_article.apply(remove_stopwords)
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  howmanybatsmenhavescored99runsinaninningsint20...  ...        sports
# 1  cricketaustraliacriticiseschannel7overstatemen...  ...        sports
# 2  warnerswifejokinglysuggestssexreasonbehindhisi...  ...        sports
# 3  femalefootballerrefusestopaytributetomaradonar...  ...        sports
# 4  afridigetsangryat21yroldafghanpaceroverfightwi...  ...        sports
#
# [5 rows x 3 columns]

# %%
df['compound'] = df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])

# %%
df.head()
# Out:
#                                        news_headline  ... compound
# 0  howmanybatsmenhavescored99runsinaninningsint20...  ...      0.0
# 1  cricketaustraliacriticiseschannel7overstatemen...  ...      0.0
# 2  warnerswifejokinglysuggestssexreasonbehindhisi...  ...      0.0
# 3  femalefootballerrefusestopaytributetomaradonar...  ...      0.0
# 4  afridigetsangryat21yroldafghanpaceroverfightwi...  ...      0.0
#
# [5 rows x 4 columns]

# %%
df
# Out:
#                                         news_headline  ... compound
# 0   howmanybatsmenhavescored99runsinaninningsint20...  ...      0.0
# 1   cricketaustraliacriticiseschannel7overstatemen...  ...      0.0
# 2   warnerswifejokinglysuggestssexreasonbehindhisi...  ...      0.0
# 3   femalefootballerrefusestopaytributetomaradonar...  ...      0.0
# 4   afridigetsangryat21yroldafghanpaceroverfightwi...  ...      0.0
# 5   f1worldchampionlewishamiltontestspositiveforco...  ...      0.0
# 6   natarajanbecomesindias232ndodicricketerreceive...  ...      0.0
# 7   kohlibecomesfastestbatsmantohit12000odirunsbre...  ...      0.0
# 8   itdoesfeelnicebabarazamoncomparisonwithviratkohli  ...      0.0
# 9   kkrnzpacerlockiefergusondevelopsfastbowlingana...  ...      0.0
# 10  29yroldspanishtennisplayerbannedfor8yearsfined...  ...      0.0
# 11  dwaynesmithsmashessixsixesinanoveragainsthisbr...  ...      0.0
# 12  lalayouare100rightamironafridistweetafterfight...  ...      0.0
# ...

# %%
df.to_csv('news.csv',index=False)

# %%
# !pip install streamlit
# Out:
# ...
#      |████████████████████████████████| 7.4MB 5.2MB/s
# ...
#      |████████████████████████████████| 102kB 10.3MB/s
# ...
#      |████████████████████████████████| 7.0MB 4.7MB/s
# ...
#      |████████████████████████████████| 133kB 49.6MB/s
# ...
#      |████████████████████████████████| 4.5MB 44.6MB/s
# ...
#      |████████████████████████████████| 163kB 43.5MB/s
# ...
#      |████████████████████████████████| 112kB 48.8MB/s
# ...
#      |████████████████████████████████| 71kB 7.0MB/s
# ...
#      |████████████████████████████████| 122kB 42.1MB/s
# ...
#      |████████████████████████████████| 71kB 8.3MB/s
# ...
#   Created wheel for watchdog: filename=watchdog-0.10.4-cp36-none-any.whl size=74841 sha256=4ae8526d736707ee6b1b4aa75d28822ce347b38c689c44ea80221c8ebeda5b00
#   Stored in directory: /root/.cache/pip/wheels/9e/11/04/5160b8815b0cc7cf574bdc6d053e510169ec264c8791b4ec3a
# ...
#   Created wheel for blinker: filename=blinker-1.4-cp36-none-any.whl size=13450 sha256=f566bba2a461f1be2c76565efc9d1ddcfe2707e04a3d4741e83f805e841bc366
# ...

# %%
# %%writefile app1.py
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

df = pd.read_csv('https://raw.githubusercontent.com/Dedeepya-1020/Sentiment-analysis--Major-project/main/news.csv')
df = pd.read_csv('https://raw.githubusercontent.com/Dedeepya-1020/Sentiment-analysis--Major-project/main/news.csv')
df['comments'] = df['comments'].astype('unicode')
df['sentiment'] = df['sentiment'].astype('unicode')
x = df.iloc[:,1].values 
y = df.iloc[:,3].values 
st.title("Sentiment Analysis of Airbnb Reviews")
st.subheader('TFIFD Vectorizer')

text_model = Pipeline([('tfidf',TfidfVectorizer()),('model',MultinomialNB())])
text_model.fit(x,y)
message = st.text_area("Enter Text","Type Here ..")
op = text_model.predict([message])
if st.button("Predict"):
  st.title(op)
# Out:
# Writing app1.py

# %%
# !pip install pyngrok==4.1.1
# Out:
# ...
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-cp36-none-any.whl size=15971 sha256=61d5a0b0904fae28d89b66076faace538bd4aa0a01fef5d7120f9027f77143d4
#   Stored in directory: /root/.cache/pip/wheels/97/71/0d/1695f7c8815c0beb3b5d9b35d6eec9243c87e6070fbe3977fa
# Successfully built pyngrok
# ...

# %%
from pyngrok import ngrok
url = ngrok.connect(port='8501')
url
# Out:
# 'http://b2afc2bd3658.ngrok.io'

# %%
# !streamlit run app1.py &
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://35.237.204.80:8501
#
#   Stopping...
